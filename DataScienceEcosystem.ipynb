# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook, we summarize key aspects of the Data Science ecosystem, including languages, libraries, and tools commonly used by data scientists.

# %% [markdown]
# ## Data Science Languages
# Some of the popular languages used by Data Scientists include:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ## Data Science Libraries
# Common libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow
# 6. Keras

# %% [markdown]
# ## Data Science Tools
#
# | Category | Tools |
# |-----------|-------|
# | Data Visualization | Tableau, Power BI, Matplotlib |
# | Data Analysis | Pandas, Excel, NumPy |
# | Machine Learning | TensorFlow, Scikit-learn, PyTorch |

# %% [markdown]
# ## Arithmetic Expressions
# Below are examples of simple arithmetic expressions used in Python.

# %%
# This code multiplies and adds numbers
(3 * 4) + 5

# %%
# This code converts minutes to hours
minutes = 200
hours = minutes / 60
hours

# %% [markdown]
# ## Objectives
# - List popular languages for Data Science
# - List commonly used libraries
# - Create a table of Data Science tools
# - Demonstrate basic arithmetic expressions
# - Convert minutes to hours using Python

# %% [markdown]
# ## Author
# **Author:** Asit More

# %% [markdown]
# ## GitHub Link
# [View this notebook on GitHub](https://github.com/YourGitHubUsername/DataScienceEcosystem)
